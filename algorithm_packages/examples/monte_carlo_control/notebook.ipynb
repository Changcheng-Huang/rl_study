# %% [markdown]
# # Monte Carlo Control on FrozenLake
#
# This notebook explains the same first-visit Monte Carlo control algorithm used by the imported experiment.

# %% [markdown]
# For each complete episode, calculate the discounted return
# $G_t = R_{t+1} + \gamma G_{t+1}$ and average returns for every first-visited state-action pair.

# %%
import gymnasium as gym
import numpy as np

# %%
env = gym.make('FrozenLake-v1', is_slippery=False)
q_table = np.zeros((env.observation_space.n, env.action_space.n))
returns_sum = np.zeros_like(q_table)
returns_count = np.zeros_like(q_table)
q_table

# %% [markdown]
# Open `experiment.py` in this package to see the complete training loop, parameter handling, progress reporting, and standardized result object.
